# %% [markdown]
# # Sampling statements on common sense platform

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scipy
import json
import polars as pl
import os
from tqdm import tqdm
import ast

import matplotlib

# Set default font to Arial
matplotlib.rcParams["font.family"] = "Arial"
matplotlib.rcParams["font.sans-serif"] = "Arial"

# %% [markdown]
# ## Load statements, ratings and human data

# %%
# All answers
print("=" * 80)
print("LOADING ANSWERS\n")
base_path = "../answers"

# Get the name of all files in the directory
files = filter(lambda s: s.endswith(".csv"), sorted(os.listdir(base_path)))
files = list(map(lambda s: os.path.join(base_path, s), files))
print("Information about survey answers are in the following files:")
for file in files:
    print("  -", file)

df_answers = pd.concat([pd.read_csv(f) for f in files])
df_answers["createdAt"] = pd.to_datetime(df_answers["createdAt"])

print("\nSummary")
print(f"- Raw number of answers: {df_answers.shape[0]:,}")
print(f"- Number of unique session IDs: {df_answers['sessionId'].unique().shape[0]:,}")
# Out:
# ================================================================================
# LOADING ANSWERS
#
# Information about survey answers are in the following files:
#   - ../answers/answers_1.csv
#   - ../answers/answers_2.csv
#
# Summary
# - Raw number of answers: 798,957
# - Number of unique session IDs: 71,082

# %%
print("=" * 80)
print("LOADING STATEMENTS\n")

df_statements = pl.read_csv("../statements/statements_1.csv")

print("Number of statements:", df_statements.shape[0])
print("Examples:")
df_statements.head(5)
# Out:
# ================================================================================
# LOADING STATEMENTS
#
# Number of statements: 10110
# Examples:
# shape: (5, 19)
# ┌─────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ id  ┆ statement  ┆ statementS ┆ origLangua ┆ … ┆ statement_ ┆ statement_ ┆ statement ┆ statement │
# │ --- ┆ ---        ┆ ource      ┆ ge         ┆   ┆ fr         ┆ es         ┆ _bn       ┆ _ar       │
# │ i64 ┆ str        ┆ ---        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │     ┆            ┆ str        ┆ str        ┆   ┆ str        ┆ str        ┆ str       ┆ str       │
# ╞═════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 1   ┆ 1 plus 1   ┆ category   ┆ En         ┆ … ┆ 1 plus 1   ┆ 1 más 1 es ┆ 1 প্লাস 1   ┆ 1 زائد 1  │
# │     ┆ is 2       ┆ response   ┆            ┆   ┆ est égal à ┆ igual a 2. ┆ সমান 2।    ┆ يساوي 2.  │
# │     ┆            ┆            ┆            ┆   ┆ 2.         ┆            ┆           ┆           │
# │ 2   ┆ 5 is alot  ┆ category   ┆ En         ┆ … ┆ 5 est      ┆ 5 es signi ┆ 5 1 এর    ┆ 5 أكبر    │
# │     ┆ bigger     ┆ response   ┆            ┆   ┆ nettement  ┆ ficativame ┆ চেয়ে উল্লে ┆ بكثير من  │
# │     ┆ than 1     ┆            ┆            ┆   ┆ plus grand ┆ nte mayor  ┆ খযোগ্যভাবে  ┆ 1.        │
# │     ┆            ┆            ┆            ┆   ┆ que…       ┆ …          ┆ ব…        ┆           │
# │ 3   ┆ a balanced ┆ category   ┆ En         ┆ … ┆ Pour       ┆ Para       ┆ ভাল স্বাস্থ্য  ┆ للحفاظ    │
# │     ┆ diet and   ┆ response   ┆            ┆   ┆ rester en  ┆ mantener   ┆ বজায় রাখতে, ┆ على صحة   │
# │     ┆ regular    ┆            ┆            ┆   ┆ bonne      ┆ una buena  ┆ একজ…      ┆ جيدة،     │
# │     ┆ ex…        ┆            ┆            ┆   ┆ santé, il… ┆ salud,…    ┆           ┆ يحتاج     │
# │     ┆            ┆            ┆            ┆   ┆            ┆            ┆           ┆ الم…      │
# │ 4   ┆ a ball is  ┆ Concept    ┆ En         ┆ … ┆ Une balle  ┆ La pelota  ┆ একটি বল   ┆ الكرة     │
# │     ┆ round      ┆ Net        ┆            ┆   ┆ est ronde. ┆ es         ┆ বৃত্তাকার।    ┆ مستديرة.  │
# │     ┆            ┆            ┆            ┆   ┆            ┆ redonda.   ┆           ┆           │
# │ 5   ┆ a baton    ┆ Concept    ┆ En         ┆ … ┆ Un joueur  ┆ Un tirador ┆ একজন ব্যাটন ┆ لن يرغب   │
# │     ┆ twirler    ┆ Net        ┆            ┆   ┆ de         ┆ de         ┆ টুয়ারলার ভাঙা  ┆ جهاز      │
# │     ┆ doesn't    ┆            ┆            ┆   ┆ matraque   ┆ bastones   ┆ আঙু…       ┆ تدوير     │
# │     ┆ want a…    ┆            ┆            ┆   ┆ ne voudr…  ┆ no quer…   ┆           ┆ العصا في  │
# │     ┆            ┆            ┆            ┆   ┆            ┆            ┆           ┆ أن…       │
# └─────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
# Individual data
print("=" * 80)
print("LOADING INDIVIDUALS' DATA\n")
base_path = "../individuals"

# Get the name of all files in the directory
files = filter(lambda s: s.endswith(".csv"), sorted(os.listdir(base_path)))
files = list(map(lambda s: os.path.join(base_path, s), files))
print("Information about survey respondents are in the following files:")
for file in files:
    print("  -", file)

df_individuals = pd.concat([pd.read_csv(f) for f in files])
df_individuals["createdAt"] = pd.to_datetime(df_individuals["createdAt"])

print("\nSummary")
print(f"- Raw number of rows: {df_individuals.shape[0]:,}")
print("\nNumber of unique session IDs")
print(
    f" - CRT: {df_individuals[df_individuals['informationType'] == 'CRT'].shape[0]:,}"
)
print(
    f" - RME: {df_individuals[df_individuals['informationType'] == 'rmeTen'].shape[0]:,}"
)
print(
    f" - Demo: {df_individuals[(df_individuals['informationType'] == 'demographics')
                               | (df_individuals['informationType'] == 'demographicsLongInternational')].shape[0]:,}"
)
# Out:
# ================================================================================
# LOADING INDIVIDUALS' DATA
#
# Information about survey respondents are in the following files:
#   - ../individuals/individuals_1.csv
#   - ../individuals/individuals_2.csv
#
# Summary
# - Raw number of rows: 126,107
#
# Number of unique session IDs
#  - CRT: 43,549
#  - RME: 41,658
#  - Demo: 40,900

# %%
df_individuals_crt = df_individuals[df_individuals["informationType"] == "CRT"].copy(
    deep=True
)
df_individuals_rme = df_individuals[df_individuals["informationType"] == "rmeTen"].copy(
    deep=True
)
df_individuals_demo = df_individuals[
    (df_individuals["informationType"] == "demographics")
    | (df_individuals["informationType"] == "demographicsLongInternational")
].copy(deep=True)

# %%
triplets_plus_answers_path = "../demo_matches/triplet_results_plus_answer.csv"
matched_triplets = pd.read_csv(triplets_plus_answers_path)
matched_triplets = matched_triplets[["answers", "crt", "rme", "demo"]].set_index("answers")
matched_triplets.head(5)
# Out:
#                                                                crt  \
# answers
# AFKsbOAjFdyRPaipeIWVAPIq_PorPuRV  PFbkwQgyw7bJMoznb3B5mVwzgoQ3XlTa
# 5pYTxD4k98-hz59OXFd3rKZViR4XFE2g  Q_gANCBosmXXUloBlgaXL-AsPnycLaz7
# 6oXWHWLsTPuZGkHld6P5c38e2MRa7E_k  Xnuej7VtARxsjnROIMvpL1RijdftyVt0
# M4QNHDNQgCuwJykO9rkVwjv7g4WH0of9  HdZtfJKkbGcyVE0EWP_ZI_71I5L5UsuC
# SNrx_UHsLbFssRvQJlQz9F-hxFuAWuyB  wHbB6GwzoF4hnwla39SiPC_s8sPql_xe
#
#                                                                rme  \
# answers
# AFKsbOAjFdyRPaipeIWVAPIq_PorPuRV  HsNOfJ9KgLpMskaX0Qj38MndXRn8h7jP
# 5pYTxD4k98-hz59OXFd3rKZViR4XFE2g  zG14BGZbKOw0i34YTgkagT-2PRrGgFXh
# 6oXWHWLsTPuZGkHld6P5c38e2MRa7E_k  4se5Vw_T7lnY7hNrDX0m8fhCT9-L9FOn
# M4QNHDNQgCuwJykO9rkVwjv7g4WH0of9  yiSGKEjfnEx54tfWB98e4mhIOtxX2e8R
# SNrx_UHsLbFssRvQJlQz9F-hxFuAWuyB  TYX1jHdP-3PfW1BB6CjybhmaEko7WiKF
#
#                                                               demo
# answers
# AFKsbOAjFdyRPaipeIWVAPIq_PorPuRV  lVy_LGMJny22Nheyn8Kjxea3ryzfjNOb
# 5pYTxD4k98-hz59OXFd3rKZViR4XFE2g  UrLPQomWxyLG-cW2pM3Oob6L2Qwtl1sz
# 6oXWHWLsTPuZGkHld6P5c38e2MRa7E_k  a-98rOxglX3JG6anZcIgKpnfcyCIxcR3
# M4QNHDNQgCuwJykO9rkVwjv7g4WH0of9  zH8Bjr8lCUJNGY5pVFdc_E_QMlbQYh2g
# SNrx_UHsLbFssRvQJlQz9F-hxFuAWuyB  DgvR0M12UketmCL-D4T5yw4MBcr9XVQB

# %% [markdown]
# Get country for each answer session.

# %%
df_individuals_demo["country_reside"] = df_individuals_demo["experimentInfo"]\
    .map(lambda s: json.loads(s)["responses"]["country_reside"])

# %%
demo_to_country = df_individuals_demo[["userSessionId", "country_reside"]
                                      ].drop_duplicates().set_index("userSessionId").dropna()

# %%
demo_to_country
# Out:
#                                   country_reside
# userSessionId
# FkNLAgvZVY9w_7ZdMSlLg7FGlbutttf2   United States
# l4JyCjo2Mq0huM9-Z78JRvxO3bERBKFH         Bahamas
# ZT_ckkMnCIWKaeFQtEjEdiIpFjx2xki3   United States
# VPgzPGNjKA4_OQ5VJvvEKyeoAe2DpZM0         Bahamas
# rv0R1OCQRzmAUCRLNO4_R8NaT1met4S1   United States
# ...                                          ...
# 09dB2c_qQCEkBgvI-8oByiRVATCch2me   United States
# Ajm3mtWnCgeiWTfPdm8nUMy85wkWpyIH  United Kingdom
# ywa6saqJt3H4RAN-qWkFt5t3nRa59PMm       Australia
# 4rD_z06rLonM8ddg410gZZhwZGUppIjb   United States
# bIxPrLQBP_1rwIiNK_jme9l7W1qtaaB5  United Kingdom
#
# [40617 rows x 1 columns]

# %% [markdown]
# Only keep ratings from users whose country of residence we know.

# %%
triplets_with_country = pd.merge(matched_triplets, demo_to_country, left_on="demo", right_index=True)

# %%
triplets_with_country
# Out:
#                                                                crt  \
# answers
# AFKsbOAjFdyRPaipeIWVAPIq_PorPuRV  PFbkwQgyw7bJMoznb3B5mVwzgoQ3XlTa
# 5pYTxD4k98-hz59OXFd3rKZViR4XFE2g  Q_gANCBosmXXUloBlgaXL-AsPnycLaz7
# 6oXWHWLsTPuZGkHld6P5c38e2MRa7E_k  Xnuej7VtARxsjnROIMvpL1RijdftyVt0
# M4QNHDNQgCuwJykO9rkVwjv7g4WH0of9  HdZtfJKkbGcyVE0EWP_ZI_71I5L5UsuC
# SNrx_UHsLbFssRvQJlQz9F-hxFuAWuyB  wHbB6GwzoF4hnwla39SiPC_s8sPql_xe
# ...                                                            ...
# lqFOduZ3XXIjWn62ADVLLNrgjGuaw8sy  lqFOduZ3XXIjWn62ADVLLNrgjGuaw8sy
# k0Iws7FihONCsSg5ih87GpDtz7_a1thp  k0Iws7FihONCsSg5ih87GpDtz7_a1thp
# nxa-71HdGqtWVVr5tgtx4zgOy00wf-lJ  nxa-71HdGqtWVVr5tgtx4zgOy00wf-lJ
# F3kO3xCeCFHaYHxQK7fdVlPwt_PzX4vm  F3kO3xCeCFHaYHxQK7fdVlPwt_PzX4vm
# 1_N377SV5j1QiT-h5y-nm4Mo5925g3m2  1_N377SV5j1QiT-h5y-nm4Mo5925g3m2
#
#                                                                rme  \
# answers
# AFKsbOAjFdyRPaipeIWVAPIq_PorPuRV  HsNOfJ9KgLpMskaX0Qj38MndXRn8h7jP
# 5pYTxD4k98-hz59OXFd3rKZViR4XFE2g  zG14BGZbKOw0i34YTgkagT-2PRrGgFXh
# 6oXWHWLsTPuZGkHld6P5c38e2MRa7E_k  4se5Vw_T7lnY7hNrDX0m8fhCT9-L9FOn
# M4QNHDNQgCuwJykO9rkVwjv7g4WH0of9  yiSGKEjfnEx54tfWB98e4mhIOtxX2e8R
# SNrx_UHsLbFssRvQJlQz9F-hxFuAWuyB  TYX1jHdP-3PfW1BB6CjybhmaEko7WiKF
# ...                                                            ...
# lqFOduZ3XXIjWn62ADVLLNrgjGuaw8sy  lqFOduZ3XXIjWn62ADVLLNrgjGuaw8sy
# k0Iws7FihONCsSg5ih87GpDtz7_a1thp  k0Iws7FihONCsSg5ih87GpDtz7_a1thp
# nxa-71HdGqtWVVr5tgtx4zgOy00wf-lJ  nxa-71HdGqtWVVr5tgtx4zgOy00wf-lJ
# F3kO3xCeCFHaYHxQK7fdVlPwt_PzX4vm  F3kO3xCeCFHaYHxQK7fdVlPwt_PzX4vm
# 1_N377SV5j1QiT-h5y-nm4Mo5925g3m2  1_N377SV5j1QiT-h5y-nm4Mo5925g3m2
#
#                                                               demo  \
# answers
# AFKsbOAjFdyRPaipeIWVAPIq_PorPuRV  lVy_LGMJny22Nheyn8Kjxea3ryzfjNOb
# 5pYTxD4k98-hz59OXFd3rKZViR4XFE2g  UrLPQomWxyLG-cW2pM3Oob6L2Qwtl1sz
# 6oXWHWLsTPuZGkHld6P5c38e2MRa7E_k  a-98rOxglX3JG6anZcIgKpnfcyCIxcR3
# M4QNHDNQgCuwJykO9rkVwjv7g4WH0of9  zH8Bjr8lCUJNGY5pVFdc_E_QMlbQYh2g
# SNrx_UHsLbFssRvQJlQz9F-hxFuAWuyB  DgvR0M12UketmCL-D4T5yw4MBcr9XVQB
# ...                                                            ...
# lqFOduZ3XXIjWn62ADVLLNrgjGuaw8sy  lqFOduZ3XXIjWn62ADVLLNrgjGuaw8sy
# k0Iws7FihONCsSg5ih87GpDtz7_a1thp  k0Iws7FihONCsSg5ih87GpDtz7_a1thp
# nxa-71HdGqtWVVr5tgtx4zgOy00wf-lJ  nxa-71HdGqtWVVr5tgtx4zgOy00wf-lJ
# F3kO3xCeCFHaYHxQK7fdVlPwt_PzX4vm  F3kO3xCeCFHaYHxQK7fdVlPwt_PzX4vm
# 1_N377SV5j1QiT-h5y-nm4Mo5925g3m2  1_N377SV5j1QiT-h5y-nm4Mo5925g3m2
#
#                                   country_reside
# answers
# AFKsbOAjFdyRPaipeIWVAPIq_PorPuRV          Canada
# 5pYTxD4k98-hz59OXFd3rKZViR4XFE2g  United Kingdom
# 6oXWHWLsTPuZGkHld6P5c38e2MRa7E_k  United Kingdom
# M4QNHDNQgCuwJykO9rkVwjv7g4WH0of9          Brazil
# SNrx_UHsLbFssRvQJlQz9F-hxFuAWuyB  United Kingdom
# ...                                          ...
# lqFOduZ3XXIjWn62ADVLLNrgjGuaw8sy   United States
# k0Iws7FihONCsSg5ih87GpDtz7_a1thp       Australia
# nxa-71HdGqtWVVr5tgtx4zgOy00wf-lJ  United Kingdom
# F3kO3xCeCFHaYHxQK7fdVlPwt_PzX4vm     New Zealand
# 1_N377SV5j1QiT-h5y-nm4Mo5925g3m2           India
#
# [31845 rows x 4 columns]

# %%
answers_with_country = pd.merge(
    df_answers,
    triplets_with_country,
    left_on="sessionId",
    right_index=True,
    how="inner"
)

# %%
answers_with_country
# Out:
#             id  I_agree            I_agree_reason  others_agree  \
# 3375      3376        1              It's obvious             1
# 3376      3377        1              It's obvious             1
# 3377      3378        1              It's obvious             1
# 3378      3379        1              It's obvious             1
# 3379      3380        1              It's obvious             1
# ...        ...      ...                       ...           ...
# 307897  798721        1           It's my opinion             1
# 307898  798722        1  It's something I learned             1
# 307899  798723        1           It's my opinion             1
# 307900  798724        1  It's something I learned             1
# 307901  798725        1           It's my opinion             1
#
#                                       others_agree_reason  \
# 3375    I think most people have good judgement with r...
# 3376    I think most people have good judgement with r...
# 3377                                         I don't know
# 3378    I think most people have good judgement with r...
# 3379    I think most people have good judgement with r...
# ...                                                   ...
# 307897  I think most people have good judgement with r...
# 307898  I think most people have good judgement with r...
# 307899  I think most people have good judgement with r...
# 307900  I think most people have good judgement with r...
# 307901            I think it's mostly a matter of opinion
#
#         perceived_commonsense clarity origLanguage  \
# 3375                        1     NaN           en
# 3376                        1     NaN           en
# 3377                        0     NaN           en
# 3378                        0     NaN           en
# 3379                        1     NaN           en
# ...                       ...     ...          ...
# 307897                      0     NaN           en
# 307898                      0     NaN           en
# 307899                      1     NaN           en
# 307900                      0     NaN           en
# 307901                      0     NaN           en
#
#                                sessionId           createdAt  \
# 3375    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0 2023-07-18 09:33:03
# 3376    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0 2023-07-18 09:33:11
# 3377    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0 2023-07-18 09:33:50
# 3378    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0 2023-07-18 09:33:55
# 3379    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0 2023-07-18 09:34:42
# ...                                  ...                 ...
# 307897  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe 2025-08-22 21:37:13
# 307898  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe 2025-08-22 21:37:28
# 307899  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe 2025-08-22 21:37:54
# 307900  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe 2025-08-22 21:38:09
# 307901  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe 2025-08-22 21:38:29
#
#                   updatedAt  statement_number  statementId clientVersion  \
# 3375    2023-07-18 09:33:03              1653         1653           NaN
# 3376    2023-07-18 09:33:11               806          806           NaN
# 3377    2023-07-18 09:33:50              4161         4161           NaN
# 3378    2023-07-18 09:33:55               831          831           NaN
# 3379    2023-07-18 09:34:42              3794         3794           NaN
# ...                     ...               ...          ...           ...
# 307897  2025-08-22 21:37:13              8995         8995       e9fc4f3
# 307898  2025-08-22 21:37:28              9401         9401       e9fc4f3
# 307899  2025-08-22 21:37:54              9658         9658       e9fc4f3
# 307900  2025-08-22 21:38:09              9775         9775       e9fc4f3
# 307901  2025-08-22 21:38:29              9879         9879       e9fc4f3
#
#                                      crt                               rme  \
# 3375    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0  nT7bs-XHJvtATColxhCUmKidpQZk0Ur0
# 3376    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0  nT7bs-XHJvtATColxhCUmKidpQZk0Ur0
# 3377    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0  nT7bs-XHJvtATColxhCUmKidpQZk0Ur0
# 3378    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0  nT7bs-XHJvtATColxhCUmKidpQZk0Ur0
# 3379    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0  nT7bs-XHJvtATColxhCUmKidpQZk0Ur0
# ...                                  ...                               ...
# 307897  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe
# 307898  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe
# 307899  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe
# 307900  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe
# 307901  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe
#
#                                     demo country_reside
# 3375    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0        Belgium
# 3376    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0        Belgium
# 3377    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0        Belgium
# 3378    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0        Belgium
# 3379    nT7bs-XHJvtATColxhCUmKidpQZk0Ur0        Belgium
# ...                                  ...            ...
# 307897  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  United States
# 307898  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  United States
# 307899  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  United States
# 307900  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  United States
# 307901  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  United States
#
# [469231 rows x 18 columns]

# %%
# Only statements ID from 8,860
answers_with_country = answers_with_country[answers_with_country["statementId"] >= 8860]
answers_with_country
# Out:
#             id  I_agree            I_agree_reason  others_agree  \
# 35660   526484        1  It's something I learned             1
# 35662   526486        1              It's obvious             1
# 35663   526487        1           It's my opinion             1
# 35665   526489        1  It's something I learned             0
# 35670   526494        0           It's my opinion             0
# ...        ...      ...                       ...           ...
# 307897  798721        1           It's my opinion             1
# 307898  798722        1  It's something I learned             1
# 307899  798723        1           It's my opinion             1
# 307900  798724        1  It's something I learned             1
# 307901  798725        1           It's my opinion             1
#
#                                       others_agree_reason  \
# 35660             I think it's mostly a matter of opinion
# 35662             I think it's mostly a matter of opinion
# 35663             I think it's mostly a matter of opinion
# 35665             I think it's mostly a matter of opinion
# 35670             I think it's mostly a matter of opinion
# ...                                                   ...
# 307897  I think most people have good judgement with r...
# 307898  I think most people have good judgement with r...
# 307899  I think most people have good judgement with r...
# 307900  I think most people have good judgement with r...
# 307901            I think it's mostly a matter of opinion
#
#         perceived_commonsense  clarity origLanguage  \
# 35660                       0  removed           en
# 35662                       1  removed           en
# 35663                       0  removed           en
# 35665                       0  removed           en
# 35670                       0  removed           en
# ...                       ...      ...          ...
# 307897                      0      NaN           en
# 307898                      0      NaN           en
# 307899                      1      NaN           en
# 307900                      0      NaN           en
# 307901                      0      NaN           en
#
#                                sessionId           createdAt  \
# 35660   KA2Ad54iudlO6D-ogNyv3QcTViQu2Jnt 2024-10-01 22:18:41
# 35662   KA2Ad54iudlO6D-ogNyv3QcTViQu2Jnt 2024-10-01 22:19:04
# 35663   dvqgem-G1utYWer-GZ4tiOJo1kPX2WyL 2024-10-01 22:19:09
# 35665   KA2Ad54iudlO6D-ogNyv3QcTViQu2Jnt 2024-10-01 22:19:23
# 35670   KA2Ad54iudlO6D-ogNyv3QcTViQu2Jnt 2024-10-01 22:19:41
# ...                                  ...                 ...
# 307897  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe 2025-08-22 21:37:13
# 307898  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe 2025-08-22 21:37:28
# 307899  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe 2025-08-22 21:37:54
# 307900  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe 2025-08-22 21:38:09
# 307901  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe 2025-08-22 21:38:29
#
#                   updatedAt  statement_number  statementId clientVersion  \
# 35660   2024-10-01 22:18:41              8876         8876       c172239
# 35662   2024-10-01 22:19:04              8882         8882       c172239
# 35663   2024-10-01 22:19:09              8882         8882       c172239
# 35665   2024-10-01 22:19:23              8885         8885       c172239
# 35670   2024-10-01 22:19:41              8875         8875       c172239
# ...                     ...               ...          ...           ...
# 307897  2025-08-22 21:37:13              8995         8995       e9fc4f3
# 307898  2025-08-22 21:37:28              9401         9401       e9fc4f3
# 307899  2025-08-22 21:37:54              9658         9658       e9fc4f3
# 307900  2025-08-22 21:38:09              9775         9775       e9fc4f3
# 307901  2025-08-22 21:38:29              9879         9879       e9fc4f3
#
#                                      crt                               rme  \
# 35660   WHbUXp5N_HhRR3Ra4xMvUaiY9qHlQdUc  D46OjVl0YKAMb48SrEDzlnPqlWiR2RWu
# 35662   WHbUXp5N_HhRR3Ra4xMvUaiY9qHlQdUc  D46OjVl0YKAMb48SrEDzlnPqlWiR2RWu
# 35663   7Osig_10-UMUBeejV_FfatZbrwj6MHyz  M0k-uq7HU46uI1y63mOVbNvBIqXieyNu
# 35665   WHbUXp5N_HhRR3Ra4xMvUaiY9qHlQdUc  D46OjVl0YKAMb48SrEDzlnPqlWiR2RWu
# 35670   WHbUXp5N_HhRR3Ra4xMvUaiY9qHlQdUc  D46OjVl0YKAMb48SrEDzlnPqlWiR2RWu
# ...                                  ...                               ...
# 307897  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe
# 307898  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe
# 307899  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe
# 307900  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe
# 307901  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe
#
#                                     demo  country_reside
# 35660   czI3MG4Sa5QkONunMXOl_jCMjEe9CpBa  United Kingdom
# 35662   czI3MG4Sa5QkONunMXOl_jCMjEe9CpBa  United Kingdom
# 35663   gxcR2Ob6mDBRbIoIMEUcsoqP29YKdla0   United States
# 35665   czI3MG4Sa5QkONunMXOl_jCMjEe9CpBa  United Kingdom
# 35670   czI3MG4Sa5QkONunMXOl_jCMjEe9CpBa  United Kingdom
# ...                                  ...             ...
# 307897  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe   United States
# 307898  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe   United States
# 307899  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe   United States
# 307900  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe   United States
# 307901  1sp423JP0jb-W6UcqrRQvNnK4YdB3jVe   United States
#
# [199040 rows x 18 columns]

# %%
I_agree = answers_with_country.pivot_table(
    index="statementId",
    columns="country_reside",
    values="I_agree",
    aggfunc="count",
    fill_value=0
).astype(int)

# %%
I_agree.to_csv("../sampling_by_country/country_statement_rating_frequency.csv")
